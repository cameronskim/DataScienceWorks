# %% [markdown]
# <a href="https://colab.research.google.com/github/cameronskim/DataScienceWorks/blob/main/chap09ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 9
#
# Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from os.path import basename, exists


def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + local)


download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkstats2.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkplot.py")

# %%
import numpy as np

import random

import thinkstats2
import thinkplot

# %% [markdown]
# ## Hypothesis testing

# %% [markdown]
# The following is a version of `thinkstats2.HypothesisTest` with just the essential methods:

# %%
class HypothesisTest(object):

    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)

    def PValue(self, iters=1000):
        self.test_stats = [self.TestStatistic(self.RunModel())
                           for _ in range(iters)]

        count = sum(1 for x in self.test_stats if x >= self.actual)
        return count / iters

    def TestStatistic(self, data):
        raise UnimplementedMethodException()

    def MakeModel(self):
        pass

    def RunModel(self):
        raise UnimplementedMethodException()

# %% [markdown]
# And here's an example that uses it to compute the p-value of an experiment where we toss a coin 250 times and get 140 heads.

# %%
class CoinTest(HypothesisTest):

    def TestStatistic(self, data):
        heads, tails = data
        test_stat = abs(heads - tails)
        return test_stat

    def RunModel(self):
        heads, tails = self.data
        n = heads + tails
        sample = [random.choice('HT') for _ in range(n)]
        hist = thinkstats2.Hist(sample)
        data = hist['H'], hist['T']
        return data

# %% [markdown]
# The p-value turns out to be about 7%, which is considered on the border of statistical significance.

# %%
ct = CoinTest((140, 110))
pvalue = ct.PValue()
pvalue
# Out:
# 0.056

# %% [markdown]
# ## Permutation test
#
# To compute the p-value of an observed difference in means, we can assume that there is no difference between the groups and generate simulated results by shuffling the data.

# %%
class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %% [markdown]
# Here's an example where we test the observed difference in pregnancy length for first babies and others.

# %%
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/nsfg.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/first.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemPreg.dct")
download(
    "https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemPreg.dat.gz"
)

# %%
import first

live, firsts, others = first.MakeFrames()
data = firsts.prglngth.values, others.prglngth.values

# %% [markdown]
# The p-value is about 17%, which means it is plausible that the observed difference is just the result of random sampling, and might not be generally true in the population.

# %%
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.17

# %% [markdown]
# Here's the distrubution of the test statistic (the difference in means) over many simulated samples:

# %%
ht.PlotCdf()
thinkplot.Config(xlabel='test statistic',
                   ylabel='CDF')

# %% [markdown]
# Under the null hypothesis, we often see differences bigger than the observed difference.

# %%
class DiffMeansOneSided(DiffMeansPermute):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = group1.mean() - group2.mean()
        return test_stat

# %% [markdown]
# If the hypothesis under test is that first babies come late, the appropriate test statistic is the raw difference between first babies and others, rather than the absolute value of the difference.  In that case, the p-value is smaller, because we are testing a more specific hypothesis.

# %%
ht = DiffMeansOneSided(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.077

# %% [markdown]
# But in this example, the result is still not statistically significant.

# %% [markdown]
# ## Difference in standard deviation
#
# In this framework, it is easy to use other test statistics.  For example, if we think the variance for first babies might be higher, we can run this test:

# %%
class DiffStdPermute(DiffMeansPermute):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = group1.std() - group2.std()
        return test_stat

# %%
# Calculate 5% of the cleaned data size
n_5_percent = int(len(cleaned) * 0.05)

# Select the first 5% of records
cleaned_subset = cleaned.head(n_5_percent)

# Prepare data for CorrelationPermute
data_subset = cleaned_subset.agepreg.values, cleaned_subset.totalwgt_lb.values

print(f"Running correlation test on the first {n_5_percent} records (5% of data)...")

# Run the test multiple times as requested
num_runs = 5
p_values_5_percent = []

for i in range(num_runs):
    ht_subset = CorrelationPermute(data_subset)
    pvalue_subset = ht_subset.PValue()
    p_values_5_percent.append(pvalue_subset)
    print(f"Run {i+1}: p-value = {pvalue_subset}")

print(f"\nObserved p-values for the first 5% of data: {p_values_5_percent}")
print(f"Median p-value: {np.median(p_values_5_percent):.4f}")
# Out:
# Running correlation test on the first 451 records (5% of data)...
# Run 1: p-value = 0.007
# Run 2: p-value = 0.015
# Run 3: p-value = 0.012
# Run 4: p-value = 0.011
# Run 5: p-value = 0.018
#
# Observed p-values for the first 5% of data: [0.007, 0.015, 0.012, 0.011, 0.018]
# Median p-value: 0.0120

# %%
from statsmodels.stats.power import TTestIndPower
import numpy as np

# Create an instance of the power analysis for independent t-test
power_analysis = TTestIndPower()

# Define parameters
effect_size = 0.1
alpha = 0.05
power = 0.8
ratio = 1.0 # Assuming equal sample sizes for the two groups
alternative = 'two-sided' # Assuming a two-sided test, which is common by default

# Calculate the required sample size (number of observations per group)
# 'nobs1' is the number of observations in the first group
nobs1 = power_analysis.solve_power(
    effect_size=effect_size,
    alpha=alpha,
    power=power,
    ratio=ratio,
    alternative=alternative
)

# Round to the nearest whole number
required_nobs = int(np.ceil(nobs1))

print(f"For a two-sample independent t-test with:")
print(f"  Effect Size: {effect_size}")
print(f"  Alpha (significance level): {alpha}")
print(f"  Desired Power: {power}")
print(f"  Alternative Hypothesis: {alternative}")
print(f"The required number of observations per group is approximately: {required_nobs}")
# Out:
# For a two-sample independent t-test with:
#   Effect Size: 0.1
#   Alpha (significance level): 0.05
#   Desired Power: 0.8
#   Alternative Hypothesis: two-sided
# The required number of observations per group is approximately: 1571

# %%
ht = DiffStdPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.078

# %% [markdown]
# But that's not statistically significant either.

# %% [markdown]
# ## Testing correlation
#
# To check whether an observed correlation is statistically significant, we can run a permutation test with a different test statistic.

# %%
class CorrelationPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        xs, ys = data
        test_stat = abs(thinkstats2.Corr(xs, ys))
        return test_stat

    def RunModel(self):
        xs, ys = self.data
        xs = np.random.permutation(xs)
        return xs, ys

# %% [markdown]
# Here's an example testing the correlation between birth weight and mother's age.

# %%
cleaned = live.dropna(subset=['agepreg', 'totalwgt_lb'])
data = cleaned.agepreg.values, cleaned.totalwgt_lb.values
ht = CorrelationPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.0

# %% [markdown]
# The reported p-value is 0, which means that in 1000 trials we didn't see a correlation, under the null hypothesis, that exceeded the observed correlation.  That means that the p-value is probably smaller than $1/1000$, but it is not actually 0.
#
# To get a sense of how unexpected the observed value is under the null hypothesis, we can compare the actual correlation to the largest value we saw in the simulations.

# %%
ht.actual, ht.MaxTestStat()
# Out:
# (np.float64(0.06883397035410904), np.float64(0.03767477438126609))

# %% [markdown]
# ## Testing proportions
#
# Here's an example that tests whether the outcome of a rolling a six-sided die is suspicious, where the test statistic is the total absolute difference between the observed outcomes and the expected long-term averages.

# %%
class DiceTest(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        observed = data
        n = sum(observed)
        expected = np.ones(6) * n / 6
        test_stat = sum(abs(observed - expected))
        return test_stat

    def RunModel(self):
        n = sum(self.data)
        values = [1, 2, 3, 4, 5, 6]
        rolls = np.random.choice(values, n, replace=True)
        hist = thinkstats2.Hist(rolls)
        freqs = hist.Freqs(values)
        return freqs

# %% [markdown]
# Here's an example using the data from the book:

# %%
data = [8, 9, 19, 5, 8, 11]
dt = DiceTest(data)
pvalue = dt.PValue(iters=10000)
pvalue
# Out:
# 0.1282

# %% [markdown]
# The observed deviance from the expected values is not statistically significant.
#
# By convention, it is more common to test data like this using the chi-squared statistic:

# %%
class DiceChiTest(DiceTest):

    def TestStatistic(self, data):
        observed = data
        n = sum(observed)
        expected = np.ones(6) * n / 6
        test_stat = sum((observed - expected)**2 / expected)
        return test_stat

# %% [markdown]
# Using this test, we get a smaller p-value:

# %%
dt = DiceChiTest(data)
pvalue = dt.PValue(iters=10000)
pvalue
# Out:
# 0.0416

# %% [markdown]
# Taking this result at face value, we might consider the data statistically significant, but considering the results of both tests, I would not draw any strong conclusions.

# %% [markdown]
# ## Chi-square test of pregnancy length

# %%
class PregLengthTest(thinkstats2.HypothesisTest):

    def MakeModel(self):
        firsts, others = self.data
        self.n = len(firsts)
        self.pool = np.hstack((firsts, others))

        pmf = thinkstats2.Pmf(self.pool)
        self.values = range(35, 44)
        self.expected_probs = np.array(pmf.Probs(self.values))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

    def TestStatistic(self, data):
        firsts, others = data
        stat = self.ChiSquared(firsts) + self.ChiSquared(others)
        return stat

    def ChiSquared(self, lengths):
        hist = thinkstats2.Hist(lengths)
        observed = np.array(hist.Freqs(self.values))
        expected = self.expected_probs * len(lengths)
        stat = sum((observed - expected)**2 / expected)
        return stat

# %% [markdown]
# If we specifically test the deviations of first babies and others from the expected number of births in each week of pregnancy, the results are statistically significant with a very small p-value.  But at this point we have run so many tests, we should not be surprised to find at least one that seems significant.

# %%
data = firsts.prglngth.values, others.prglngth.values
ht = PregLengthTest(data)
p_value = ht.PValue()
print('p-value =', p_value)
print('actual =', ht.actual)
print('ts max =', ht.MaxTestStat())
# Out:
# p-value = 0.0
# actual = 101.50141482893264
# ts max = 31.20452540819244

# %% [markdown]
# ## Power
#
# Here's the function that estimates the probability of a non-significant p-value even is there really is a difference between the groups.

# %%
def FalseNegRate(data, num_runs=1000):
    """Computes the chance of a false negative based on resampling.

    data: pair of sequences
    num_runs: how many experiments to simulate

    returns: float false negative rate
    """
    group1, group2 = data
    count = 0

    for i in range(num_runs):
        sample1 = thinkstats2.Resample(group1)
        sample2 = thinkstats2.Resample(group2)
        ht = DiffMeansPermute((sample1, sample2))
        p_value = ht.PValue(iters=101)
        if p_value > 0.05:
            count += 1

    return count / num_runs

# %%
neg_rate = FalseNegRate(data)
neg_rate
# Out:
# 0.684

# %% [markdown]
# In this example, the false negative rate is 70%, which means that the power of the test (probability of statistical significance if the actual difference is 0.078 weeks) is only 30%.

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise:** As sample size increases, the power of a hypothesis test increases, which means it is more likely to be positive if the effect is real. Conversely, as sample size decreases, the test is less likely to be positive even if the effect is real.
#
# To investigate this behavior, run the tests in this chapter with different subsets of the NSFG data. You can use `thinkstats2.SampleRows` to select a random subset of the rows in a DataFrame.
#
# What happens to the p-values of these tests as sample size decreases? What is the smallest sample size that yields a positive test?

# %% [markdown]
# **Exercise:** In Section 9.3, we simulated the null hypothesis by permutation; that is, we treated the observed values as if they represented the entire population, and randomly assigned the members of the population to the two groups.
#
# An alternative is to use the sample to estimate the distribution for the population, then draw a random sample from that distribution. This process is called resampling. There are several ways to implement resampling, but one of the simplest is to draw a sample with replacement from the observed values, as in Section 9.10.
#
# Write a class named `DiffMeansResample` that inherits from `DiffMeansPermute` and overrides `RunModel` to implement resampling, rather than permutation.
#
# Use this model to test the differences in pregnancy length and birth weight. How much does the model affect the results?

# %%
ct_new = CoinTest((290, 210))
pvalue_new = ct_new.PValue()
pvalue_new
# Out:
# 0.0

# %% [markdown]
# # Task
# Analyze the new coin flip data by instantiating the `CoinTest` class with 290 heads and 210 tails, and then calculate its p-value.

# %% [markdown]
# ## Analyze the new coin flip data
#
# ### Subtask:
# Instantiate the `CoinTest` class with the new data (290 heads, 210 tails) and calculate the p-value.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The task involved calculating the p-value for new coin flip data. The specific calculated p-value from the solving process was not provided in the given context.
#
# ### Data Analysis Key Findings
# *   A coin flip test was initiated using the `CoinTest` class.
# *   The data provided for the test consisted of 290 heads and 210 tails, summing up to a total of 500 coin flips.
# *   The primary objective of this analysis was to calculate the p-value to determine the statistical significance of the observed head/tail distribution, which would indicate whether the coin is biased.
#
# ### Insights or Next Steps
# *   Once the p-value is calculated, it should be compared against a pre-defined significance level (e.g., 0.05) to determine if there is sufficient evidence to reject the null hypothesis that the coin is fair.
# *   Depending on the p-value, further actions could involve concluding whether the coin is statistically biased or suggesting that more data is needed for a definitive conclusion.

# %% [markdown]
# # Task
# Investigate the effect of sample size on p-values for pregnancy length differences by defining a function to run the `DiffMeansPermute` test for varying sample sizes. Iterate through a range of decreasing sample sizes, for each size run multiple simulations using `thinkstats2.SampleRows` on the `firsts.prglngth.values` and `others.prglngth.values` data, collect the p-values, calculate the median p-value, and store the results. Finally, plot the median p-value against the total sample size and analyze the trend, reporting if a 'positive test' (median p-value < 0.05) is achieved and the smallest sample size at which it occurs.

# %% [markdown]
# ## Investigate the effect of sample size on p-values for pregnancy length difference
#
# ### Subtask:
# Define a function to run the `DiffMeansPermute` test for varying sample sizes. Iterate through a range of decreasing sample sizes, and for each size, run multiple simulations using `thinkstats2.SampleRows`. Collect the p-values, calculate the median p-value for each sample size, and store the results.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The task aims to determine if a 'positive test' (median p-value < 0.05) is achieved and to identify the smallest sample size at which it occurs for the pregnancy length difference. This question will be answered after the described simulation and analysis are completed.
#
# ### Data Analysis Key Findings
# The provided information outlines the plan for the analysis but does not yet contain executed results or numerical findings. Therefore, no key findings can be reported at this stage.
#
# ### Insights or Next Steps
# *   The next step is to execute the defined function and simulation process to generate the p-values for varying sample sizes.
# *   Once the simulations are complete, the median p-values should be plotted against the total sample size to identify the trend and answer the core question regarding the 'positive test' threshold.
